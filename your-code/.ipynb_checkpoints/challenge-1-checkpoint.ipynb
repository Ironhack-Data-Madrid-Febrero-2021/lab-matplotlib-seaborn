# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# Answer all questions by drawing a graph. Then explain.

# %% [markdown]
# **0. Load seaborn dataset "tips"**

# %%
import pandas as pd
import seaborn as sb
df = sb.load_dataset('tips')
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# **1. What is the prefered day for eating?**

# %%
sns.countplot(x=df.day);

# %%
#Based on the graph, we can conclude that out of the 4 days when the restaurant operates, the preferred day for its customers to visit is on Saturday.

# %%
pref_day = df['day'].mode().iat[0]
print(pref_day)
# Out:
# Sat

# %% [markdown]
# **2. What days of the week has more men than women payers?**

# %%
sns.countplot(x=df.day,
              hue=df.sex,
              palette="ch:.25");

# %%
#From the previous graph, it is possible to know that on Saturdays and Sundays the restaurant receives serves more male than female clients.

# %% [markdown]
# **3. Do you think bill amounts change considerably depending on smoking?**

# %%
sns.countplot(x=df.total_bill,
              hue=df.smoker,
              palette='Blues');

# %%
#Accordingly to the graph, there's no significant difference between the consumption of the customers than smoke than the ones' who do not smoke. They all seem to pay the approximate the same amount for the service.

# %% [markdown]
# **4. Is tip correlated to total_bill? Draw a scatter plot**

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.scatterplot(x=df.tip,
               y=df.total_bill);

# %%
#After evaluating the correlation between the amount that clients tip after paying their bill, it is plausible to conclude that accordingly to their consumption amount they tend to tip for the service

# %% [markdown]
# **BONUS**: Draw a graph of your choice with 2 numerical variables and 2 categorical variable (HINT: use `hue` and `style`). Do you find it useful?

# %%
# %matplotlib notebook

# %%
sns.scatterplot(x="total_bill",
                y="tip",
                style="time",
                hue='sex',
                data=df);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Due to the size of this graph is quite difficult to identify correctly the patrons of both, the female and male customers, based on the time of the day they go to the restaurant. It would be ideal to evalue each one in one single graph for each sex group respectively.
