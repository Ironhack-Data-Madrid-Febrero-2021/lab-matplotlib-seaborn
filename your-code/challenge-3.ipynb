# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include=['float64', 'int64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#your code here- categorical variable
titanic.select_dtypes(include = ['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here

fig = plt.figure()
fig, ax = plt.subplots(figsize=(12,6));
plt.style.use('classic')

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
plt.hist(titanic.Age);

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(12,6));
plt.style.use('classic')

ax1.hist(x = titanic.Age, bins = 10);
ax1.set_title('Bins 10')

ax2.hist(x = titanic.Age, bins = 20);
ax2.set_title('Bins 20')

ax3.hist(x = titanic.Age, bins = 50);
ax3.set_title('Bins 50')
# Out:
# Text(0.5, 1.0, 'Bins 50')

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
'''
Whether if we need a detailed data for studing or only a tendence
10 bins give us a general view of the situation, but we lose lot of detaits
50 bins allow us to understand every particularity, as the frequency of the children onboard from 0 to 4 was higher 
than the frequency of children 5 to 14. It rises again on teenagers
# Out:
#   File "<ipython-input-10-a643127b48fc>", line 5
#     than the frequency of children 5 to 14. It rises again on teenagers
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.histplot(y = titanic.Age);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
plt.hist(x = titanic.Gender);
plt.title('Gender with Matplotlib')
# Out:
# Text(0.5, 1.0, 'Gender with Matplotlib')

# %%
sns.countplot(titanic.Gender).set_title('Gender with Seaborn');
# Out:
# /Users/victor/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
sns.countplot(titanic.Pclass, palette = 'Blues');
# Out:
# /Users/victor/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
plt.boxplot(titanic.Age);

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
'''it tells us that:
    - the mean age was near to 29-30 years old
    - that the 50% of the passengers were between 21 (aprox) and 37(aprox)
    - the younger passenger was a newborn
    - the oldest passenger was 80
    - there were some outsiders older than 60

'''
# Out:
# 'it tells us that:\n    - the mean age was near to 29-30 years old\n    - that the 50% of the passengers were between 21 (aprox) and 37(aprox)\n    - the younger passenger was a newborn\n    - the oldest passenger was 80\n    - there were some outsiders older than 60\n\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
sns.histplot(y = titanic.Age);

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
'''
the concrete distribution 
'''
# Out:
# '\nthe concrete distribution \n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
plt.scatter(titanic.Age, titanic.Fare, c = 'g')
plt.ylabel('Fare')
plt.xlabel('Passenger age')
plt.title('Relationship Fare-Age')
# Out:
# Text(0.5, 1.0, 'Relationship Fare-Age')

# %%
sns.scatterplot(titanic.Age, titanic.Fare)
# Out:
# /Users/victor/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
corr = titanic.corr()
heatmap = sns.heatmap(corr)

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
'''
There is a correlation between the age of the passenger and the passenger-class, what is also related to the fare
+ age = + class
+ class = + fare

so probably, the older the passenger is, it's likely to had paid a higher fare
'''

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
sns.boxplot(x = titanic.Pclass,
           y = titanic.Age);

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
fg = sns.FacetGrid(titanic, col = "Gender")

fg.map(plt.hist, "Age", edgecolor ="w").add_legend() 

plt.show()
